# %%
## plotting x and y
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[40,50,60,70,80]
plt.plot(x,y)

# %%
import pandas as pd

# %%
data={
    'Name':['ram','shyam','hari','om','jai'],
    'Age':[25,None,45,23,None],
    'Salary':[5000,6000,7000,None,None]

}
df=pd.DataFrame(data)
print('Original DataFrame')
print(df)

print(df.isnull().sum())
print(df.isnull().mean()*100)

df_drop=df.dropna()
print(df_drop)
# Out:
# Original DataFrame
#     Name   Age  Salary
# 0    ram  25.0  5000.0
# 1  shyam   NaN  6000.0
# 2   hari  45.0  7000.0
# 3     om  23.0     NaN
# 4    jai   NaN     NaN
# Name      0
# Age       2
# Salary    2
# dtype: int64
# Name       0.0
# Age       40.0
# Salary    40.0
# dtype: float64
#    Name   Age  Salary
# 0   ram  25.0  5000.0
# 2  hari  45.0  7000.0

# %%
data={
    'Name':['ram','shyam','hari','om','jai'],
    'Age':[25,None,45,23,None],
    'Salary':[5000,6000,7000,None,None]

}
df=pd.DataFrame(data)
print('Original DataFrame')
print(df)


df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Salary'].fillna(df['Salary'].mean(),inplace=True)
print(df)
# Out:
# Original DataFrame
#     Name   Age  Salary
# 0    ram  25.0  5000.0
# 1  shyam   NaN  6000.0
# 2   hari  45.0  7000.0
# 3     om  23.0     NaN
# 4    jai   NaN     NaN
#     Name   Age  Salary
# 0    ram  25.0  5000.0
# 1  shyam  31.0  6000.0
# 2   hari  45.0  7000.0
# 3     om  23.0  6000.0
# 4    jai  31.0  6000.0

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

df=pd.read_csv('students_result_with_cities.csv')

df_label=df.copy()

le=LabelEncoder()
df_label['Gender_Encoded']=le.fit_transform(df_label['Gender'])
df_label['Result_Encoded']=le.fit_transform(df_label['Result'])

print('Dataset after encoding')
print(df_label[['Name','Gender','Gender_Encoded','Result','Result_Encoded']])
# Out:
# Dataset after encoding
#                 Name  Gender  Gender_Encoded Result  Result_Encoded
# 0       Aarav Sharma    Male               1   Pass               1
# 1      Sita Bhandari  Female               0   Pass               1
# 2        Rohan Thapa    Male               1   Fail               0
# 3           Priya KC  Female               0   Pass               1
# 4        Manish Lama    Male               1   Pass               1
# 5       Anita Gurung  Female               0   Fail               0
# 6          Kiran Rai    Male               1   Pass               1
# 7        Mina Khadka  Female               0   Pass               1
# 8      Bikash Tamang    Male               1   Fail               0
# 9     Sarita Neupane  Female               0   Pass               1
# 10   Deepak Shrestha    Male               1   Pass               1
# 11       Rachana Oli  Female               0   Fail               0
# ...

# %% [markdown]
# ## One-hot encoding

# %%
df_encoded=pd.get_dummies(df_label, columns=['City'])
print('One hot encoded data (City)')
print(df_encoded)
# Out:
# One hot encoded data (City)
#                 Name  Gender Result  Gender_Encoded  Result_Encoded  \
# 0       Aarav Sharma    Male   Pass               1               1
# 1      Sita Bhandari  Female   Pass               0               1
# 2        Rohan Thapa    Male   Fail               1               0
# 3           Priya KC  Female   Pass               0               1
# 4        Manish Lama    Male   Pass               1               1
# 5       Anita Gurung  Female   Fail               0               0
# 6          Kiran Rai    Male   Pass               1               1
# 7        Mina Khadka  Female   Pass               0               1
# 8      Bikash Tamang    Male   Fail               1               0
# 9     Sarita Neupane  Female   Pass               0               1
# 10   Deepak Shrestha    Male   Pass               1               1
# 11       Rachana Oli  Female   Fail               0               0
# ...

# %% [markdown]
# ## Feature Scaling

# %%
# from sklearn.preprocessing import StandardScaler

# scaler=StandardScaler()
# X_scaled=scaler.fit_transform()

# scaler=MinMxScaler()
# X_scaled=scaler.fit_transform

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

data={
    'study_hours':[1,2,3,4,5],
    'TestScore':[40,50,60,70,70]

}
df=pd.DataFrame(data)

standard_scaled=StandardScaler().fit_transform(df)

print('Standard Scaler Output')
print(pd.DataFrame(standard_scaled, columns=['study_hours','TestScore']))

min_max_Scaled=MinMaxScaler().fit_transform(df)
print('Min Max Scaled Output')
print(pd.DataFrame(min_max_Scaled, columns=['study_hours','TestScore']))


x=df[['study_hours']]
y=df[['TestScore']]

X_train, X_test, y_train ,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

print('Training data')
print(X_train)

print('Testing Data')
print(X_test)


print('Training data')
print(y_train)

print('Testing Data')
print(y_test)
# Out:
# Standard Scaler Output
#    study_hours  TestScore
# 0    -1.414214  -1.543487
# 1    -0.707107  -0.685994
# 2     0.000000   0.171499
# 3     0.707107   1.028992
# 4     1.414214   1.028992
# Min Max Scaled Output
#    study_hours  TestScore
# 0         0.00   0.000000
# 1         0.25   0.333333
# 2         0.50   0.666667
# 3         0.75   1.000000
# 4         1.00   1.000000
# Training data
#    study_hours
# 4            5
# 2            3
# 0            1
# 3            4
# Testing Data
#    study_hours
# 1            2
# Training data
#    TestScore
# 4         70
# 2         60
# 0         40
# 3         70
# Testing Data
#    TestScore
# 1         50
