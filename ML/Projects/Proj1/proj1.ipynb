# %%
import pandas as pd

# %%
from sklearn.linear_model import  LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
import matplotlib.pyplot as plt
import numpy as np

# %%
#load data
data=pd.read_csv('student_data.csv')

#input
X=data[['Hours_Studied']]
y=data['Exam_Score']


#train model
model=LinearRegression()
model.fit(X,y)
predicted_scores=model.predict(X)

#Valid regression metrics
mae=mean_absolute_error(y,predicted_scores)
mse=mean_squared_error(y,predicted_scores)
rmse=np.sqrt(mse)
r2=r2_score(y,predicted_scores)

##show results
print('Mean Absolute Error',round(mae,2))
print('Mean Squared Error',round(mse,1))
print('Root mean squared error ', round(rmse,2))
print('R^2 Score:: ',round(rmse,2))
# Out:
# Mean Absolute Error 2.51
# Mean Squared Error 12.1
# Root mean squared error  3.48
# R^2 Score::  3.48

# %%
##Output prediction
hours=float(input('Enter hours studied:'))
predicted_score=model.predict([[hours]])
print(f'Predicted score is {predicted_score}')
# Out:
# Predicted score is [68.11066807]
# c:\Users\Madhusudan Bhandari\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
##plotting Histogram
plt.figure(figsize=(10,6))
plt.hist(data['Exam_Score'], bins=30, color='skyblue', edgecolor='black')
plt.title('Final score distribution')
plt.xlabel('Final exam score')
plt.ylabel('Number of students')
plt.grid(True)
plt.show()

# %%
##Scatter Regression Line
plt.figure(figsize=(10,6))
plt.scatter(X,y, color='blue', label='Actual Scores')
plt.plot(X, predicted_scores, color='red', label='Predicted Dcores (Regression Lne)')
plt.title('Model Predictions vs Actual Scores')
plt.xlabel('Study hours per week')
plt.ylabel('Final Output')
plt.grid(True)
plt.show()
