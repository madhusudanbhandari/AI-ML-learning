# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
X=[1,2,3,4]
y=[5,3,7,2]
plt.plot(X,y)
plt.show()

# %%
days=['mon','tue','wed','thurs']
sales=[23,34,12,43]

plt.plot(days,sales)
plt.title('Sales Data')
plt.xlabel('Days')
plt.ylabel('Sales')
plt.show()
